# %% [markdown]
# # 13.4 그래프 학습의 확장 — 실습 노트북
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SuminHan/book-ml/blob/main/notebooks/ml1/chapter13_4_graph_extensions.ipynb)
#
# 책 본문: [13.4 그래프 학습의 확장](https://smhanlab.com/book-ml/kor/ml1/chapter13.html)
#
# 작은 합성 데이터로 spatio-temporal 그래프(STGCN 스타일)와 단백질 그래프 분류의 감을 잡아봅니다.

# %% [markdown]
# [STUB — cq가 채울 자리: 가벼운 합성 데이터 데모 (IBM AML World/DCRNN 원 코드 이식 아님)]

# %%
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
