# %% [markdown]
# # 13.1 Random Walk 기초 — 실습 노트북
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SuminHan/book-ml/blob/main/notebooks/ml1/chapter13_1_random_walk.ipynb)
#
# 책 본문: [13.1 Random Walk 기초](https://smhanlab.com/book-ml/kor/ml1/chapter13.html)
#
# 그래프 위의 무작위 걷기와 그 정상분포를 카라테 클럽 그래프로 직접 계산해봅니다.

# %% [markdown]
# [STUB — cq가 채울 자리: 정상분포 시뮬레이션 + 이론값(deg(i)/2|E|) 비교 코드]

# %%
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
